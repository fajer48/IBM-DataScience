# %% [markdown]
# # The Battle of Neighborhood: Districts of Seoul - Where to Visit

# %% [markdown]
# ## 1. Business Understanding

# %% [markdown]
# ### 1.1 Discussion of the background

# %% [markdown]
# Seoul is South Korea's capital, and largest city. The town sits on the Han River in the northwest region of South Korea.
# Compared to this, Han River was used as a trading route to China. Han River is no longer used for navigation today, since its estuary is at the North-South Korean border. Given that South Korea is small, with Seoul a mere four-hour train ride from even the most remote area, it's easy to go full holiday mode and explore the country at large. Jejudo, which may just be the most popular destination for holidays. Jejudo is part of 12 Unesco World Heritage Sites roster for the region. These national treasures include royal palaces, graves, shrines and well-preserved villages in the hanok.

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://images.unsplash.com/photo-1539646899451-eff372db037f?ixlib=rb-1.2.1&ixid=eyJhcHBfaWQiOjEyMDd9&auto=format&fit=crop&w=1000&q=80", width=800, height=800)
# Out:
# <img src="https://images.unsplash.com/photo-1539646899451-eff372db037f?ixlib=rb-1.2.1&ixid=eyJhcHBfaWQiOjEyMDd9&auto=format&fit=crop&w=1000&q=80" width="800" height="800"/>

# %% [markdown]
# Korea has 2,413 kilometers of seaside, with large coastal plains to the west and south. Also, 3,000 remote uninhabited offshore islands.  Seoul has twenty five districts, which makes it difficult to decide where to visit and stay.

# %% [markdown]
# ### 1.2 Business Problem

# %% [markdown]
# As Seoul have 23 districts, it is difficult for travelers, to choose which district to visit. District reviews are subjective and differ from people, you can’t just depend on that. It is more important to consider other aspects like price, distance, venues and entertainment, that can highly influence one's experience. There are alot of aspects to consider. For example, if you are traveling for less than two weeks and have a fixed schedule, it is reccomended to book accommodationfor the duration of your trip if it gives you peace of mind. Other aspects include the following but are not limited to. The main objective is to find ideal venues where travellers and tourists can find the best suitable to them.

# %% [markdown]
# -How does price vary for different districts?
#
# -How does transportation affect districts?
#
# -Do you prefer visiting historical or modern venues?
#
# -Which district has more entertainment activites?
#
# -Which districts are more safe?

# %% [markdown]
# ### 1.3 Target Audience

# %% [markdown]
# -<strong>Travelling Solo</strong><br>
# The people that are travelling alone, looking for an experience away from their comfort zone.
#
# -<strong>Travelling with family or friends</strong><br>
# The people you're traveling with or lack of it can make some places and experiences more feasible than others. You have to wonder what kind of place everyone traveling will enjoy.

# %% [markdown]
# ## 3. Data Requirements

# %% [markdown]
# <strong>Seoul districts will be analysed in this project.</strong><br> Following are the datasets that will be used:
#
# <h4>Seoul Districts Dataset</h4> This dataset avaliable from Wikipedia. This is the core <a href='https://en.wikipedia.org/wiki/List_of_districts_of_Seoul' >dataset</a> that will be used.</br>
#
#
# <h4>Neighbourhoods</h4> The data of the neighbourhoods will be gathered using scraping techique by <a href= 'https://www.crummy.com/software/BeautifulSoup/bs4/doc/'> BeautifulSoup </a>. It's a Python based library.
#
# <h4>FourSquare API</h4> The Venue data will be gathered by passing in the parametered to the <a href= 'https://foursquare.com/' >FourSquare API</a>. Also, generating a DataFrame to maintain all the venue informtaion to their prespective districts.
#
# <h4>Geocoding</h4> The data generated will in the csv file seoul.csv will be retrieved in a <a href= 'https://pandas.pydata.org/' >Panda </a>DataFrame. Both latitude and lontitiude will be established using Google Maps and <a href ='https://developers.google.com/maps/documentation/geocoding/start'>Geocoding API</a>. Both will be stored into the DataFrame.
